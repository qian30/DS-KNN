# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# %%
# x_train, x_test, y_train, y_test
def getData(par_feature):
    dataset = load_breast_cancer()
    feature = pd.DataFrame(dataset.data, columns=dataset.feature_names)
    target = pd.Series(dataset.target, name='target')
    df = pd.concat([feature, target], axis=1)
    myset = list(train_test_split(
        feature[par_feature], target, test_size=0.3, 
        random_state=42, stratify=target
    ))
    return myset

# %%
def Std(myset):
    ss = StandardScaler()
    return ss.fit_transform(myset[0]), ss.transform(myset[1])

# %%
def predict(myset, k):
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(myset[0], myset[2])
    return knn.predict(myset[1])

# %%
def result(test, pred):
    accuracy = round(accuracy_score(test, pred), 2)
    precision = round(precision_score(test, pred), 2)
    recall = round(recall_score(test, pred), 2)
    f1 = round(f1_score(test, pred), 2)
    return (accuracy, precision, recall, f1)

# %%
def run(f, std, k):
    myset = getData(f)
    if std == True:
        myset[0], myset[1] = Std(myset)
    y_pred = predict(myset, k)
    metric = result(myset[3], y_pred)
    return metric

# %%
def show(metric):
    met = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
    for i in range(4):
        print(met[i], metric[i])

# %%
load_breast_cancer().feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
areas = ['mean radius', 'mean perimeter', 'mean area']
textures = ['mean texture', 'mean smoothness']
pairs = []
flist = []
for area in areas:
    for texture in textures:
        for std in ['std', 'no std']:
            pairs.append(f'{area} + {texture} + {std}')
        flist.append([area, texture])

# %%
def showDF(k):
    print('k =', k)
    sol = [[] for i in range(4)]
    for f in flist:
        for tf in [True, False]:
            ans = run(f, tf, k)
            for i in range(4):
                sol[i].append(ans[i])
    return sol

# %%
pd.DataFrame(showDF(1), columns=pairs)
# Out:
# k = 1
#    mean radius + mean texture + std  mean radius + mean texture + no std  \
# 0                              0.84                                 0.82
# 1                              0.90                                 0.88
# 2                              0.84                                 0.83
# 3                              0.87                                 0.86
#
#    mean radius + mean smoothness + std  \
# 0                                 0.87
# 1                                 0.94
# 2                                 0.84
# 3                                 0.89
#
#    mean radius + mean smoothness + no std  \
# 0                                    0.86
# 1                                    0.88
# 2                                    0.90
# 3                                    0.89
#
#    mean perimeter + mean texture + std  \
# 0                                 0.85
# 1                                 0.90
# 2                                 0.85
# 3                                 0.88
#
#    mean perimeter + mean texture + no std  \
# 0                                    0.87
# 1                                    0.91
# 2                                    0.87
# 3                                    0.89
#
#    mean perimeter + mean smoothness + std  \
# 0                                    0.85
# 1                                    0.92
# 2                                    0.83
# 3                                    0.87
#
#    mean perimeter + mean smoothness + no std  mean area + mean texture + std  \
# 0                                       0.84                            0.82
# 1                                       0.88                            0.87
# 2                                       0.86                            0.84
# 3                                       0.87                            0.85
#
#    mean area + mean texture + no std  mean area + mean smoothness + std  \
# 0                               0.85                               0.88
# 1                               0.87                               0.93
# 2                               0.91                               0.87
# 3                               0.89                               0.90
#
#    mean area + mean smoothness + no std
# 0                                  0.84
# 1                                  0.85
# 2                                  0.90
# 3                                  0.87

# %%
pd.DataFrame(showDF(2), columns=pairs)
# Out:
# k = 2
#    mean radius + mean texture + std  mean radius + mean texture + no std  \
# 0                              0.82                                 0.81
# 1                              0.94                                 0.94
# 2                              0.76                                 0.75
# 3                              0.84                                 0.83
#
#    mean radius + mean smoothness + std  \
# 0                                 0.82
# 1                                 0.98
# 2                                 0.73
# 3                                 0.83
#
#    mean radius + mean smoothness + no std  \
# 0                                    0.82
# 1                                    0.89
# 2                                    0.81
# 3                                    0.85
#
#    mean perimeter + mean texture + std  \
# 0                                 0.84
# 1                                 0.95
# 2                                 0.79
# 3                                 0.86
#
#    mean perimeter + mean texture + no std  \
# 0                                    0.87
# 1                                    0.96
# 2                                    0.83
# 3                                    0.89
#
#    mean perimeter + mean smoothness + std  \
# 0                                    0.82
# 1                                    0.98
# 2                                    0.73
# 3                                    0.83
#
#    mean perimeter + mean smoothness + no std  mean area + mean texture + std  \
# 0                                       0.82                            0.81
# 1                                       0.90                            0.94
# 2                                       0.79                            0.74
# 3                                       0.85                            0.83
#
#    mean area + mean texture + no std  mean area + mean smoothness + std  \
# 0                               0.86                               0.84
# 1                               0.93                               0.98
# 2                               0.84                               0.76
# 3                               0.88                               0.85
#
#    mean area + mean smoothness + no std
# 0                                  0.82
# 1                                  0.90
# 2                                  0.81
# 3                                  0.85

# %%
pd.DataFrame(showDF(3), columns=pairs)
# Out:
# k = 3
#    mean radius + mean texture + std  mean radius + mean texture + no std  \
# 0                              0.86                                 0.87
# 1                              0.89                                 0.90
# 2                              0.89                                 0.88
# 3                              0.89                                 0.89
#
#    mean radius + mean smoothness + std  \
# 0                                 0.87
# 1                                 0.94
# 2                                 0.84
# 3                                 0.89
#
#    mean radius + mean smoothness + no std  \
# 0                                    0.85
# 1                                    0.87
# 2                                    0.91
# 3                                    0.89
#
#    mean perimeter + mean texture + std  \
# 0                                 0.90
# 1                                 0.93
# 2                                 0.91
# 3                                 0.92
#
#    mean perimeter + mean texture + no std  \
# 0                                    0.89
# 1                                    0.93
# 2                                    0.90
# 3                                    0.91
#
#    mean perimeter + mean smoothness + std  \
# 0                                    0.88
# 1                                    0.96
# 2                                    0.84
# 3                                    0.90
#
#    mean perimeter + mean smoothness + no std  mean area + mean texture + std  \
# 0                                       0.87                            0.84
# 1                                       0.88                            0.86
# 2                                       0.92                            0.89
# 3                                       0.90                            0.88
#
#    mean area + mean texture + no std  mean area + mean smoothness + std  \
# 0                               0.87                               0.84
# 1                               0.88                               0.93
# 2                               0.92                               0.81
# 3                               0.90                               0.87
#
#    mean area + mean smoothness + no std
# 0                                  0.88
# 1                                  0.87
# 2                                  0.94
# 3                                  0.91

# %%
pd.DataFrame(showDF(4), columns=pairs)
# Out:
# k = 4
#    mean radius + mean texture + std  mean radius + mean texture + no std  \
# 0                              0.88                                 0.87
# 1                              0.93                                 0.92
# 2                              0.88                                 0.87
# 3                              0.90                                 0.89
#
#    mean radius + mean smoothness + std  \
# 0                                 0.86
# 1                                 0.97
# 2                                 0.80
# 3                                 0.88
#
#    mean radius + mean smoothness + no std  \
# 0                                    0.83
# 1                                    0.88
# 2                                    0.85
# 3                                    0.86
#
#    mean perimeter + mean texture + std  \
# 0                                 0.89
# 1                                 0.95
# 2                                 0.87
# 3                                 0.91
#
#    mean perimeter + mean texture + no std  \
# 0                                    0.90
# 1                                    0.96
# 2                                    0.88
# 3                                    0.92
#
#    mean perimeter + mean smoothness + std  \
# 0                                    0.88
# 1                                    0.97
# 2                                    0.83
# 3                                    0.89
#
#    mean perimeter + mean smoothness + no std  mean area + mean texture + std  \
# 0                                       0.85                            0.87
# 1                                       0.89                            0.91
# 2                                       0.87                            0.87
# 3                                       0.88                            0.89
#
#    mean area + mean texture + no std  mean area + mean smoothness + std  \
# 0                               0.88                               0.85
# 1                               0.91                               0.97
# 2                               0.90                               0.79
# 3                               0.90                               0.87
#
#    mean area + mean smoothness + no std
# 0                                  0.86
# 1                                  0.88
# 2                                  0.90
# 3                                  0.89

# %%
pd.DataFrame(showDF(5), columns=pairs)
# Out:
# k = 5
#    mean radius + mean texture + std  mean radius + mean texture + no std  \
# 0                              0.87                                 0.86
# 1                              0.89                                 0.88
# 2                              0.90                                 0.90
# 3                              0.89                                 0.89
#
#    mean radius + mean smoothness + std  \
# 0                                 0.87
# 1                                 0.95
# 2                                 0.83
# 3                                 0.89
#
#    mean radius + mean smoothness + no std  \
# 0                                    0.87
# 1                                    0.86
# 2                                    0.93
# 3                                    0.90
#
#    mean perimeter + mean texture + std  \
# 0                                 0.88
# 1                                 0.91
# 2                                 0.91
# 3                                 0.91
#
#    mean perimeter + mean texture + no std  \
# 0                                    0.88
# 1                                    0.92
# 2                                    0.89
# 3                                    0.90
#
#    mean perimeter + mean smoothness + std  \
# 0                                    0.87
# 1                                    0.93
# 2                                    0.85
# 3                                    0.89
#
#    mean perimeter + mean smoothness + no std  mean area + mean texture + std  \
# 0                                       0.87                            0.87
# 1                                       0.87                            0.89
# 2                                       0.93                            0.91
# 3                                       0.90                            0.90
#
#    mean area + mean texture + no std  mean area + mean smoothness + std  \
# 0                               0.88                               0.87
# 1                               0.88                               0.94
# 2                               0.93                               0.84
# 3                               0.90                               0.89
#
#    mean area + mean smoothness + no std
# 0                                  0.87
# 1                                  0.87
# 2                                  0.93
# 3                                  0.90

# %%
pd.DataFrame(showDF(6), columns=pairs)
# Out:
# k = 6
#    mean radius + mean texture + std  mean radius + mean texture + no std  \
# 0                              0.89                                 0.89
# 1                              0.93                                 0.93
# 2                              0.89                                 0.89
# 3                              0.91                                 0.91
#
#    mean radius + mean smoothness + std  \
# 0                                 0.85
# 1                                 0.95
# 2                                 0.81
# 3                                 0.87
#
#    mean radius + mean smoothness + no std  \
# 0                                    0.85
# 1                                    0.86
# 2                                    0.90
# 3                                    0.88
#
#    mean perimeter + mean texture + std  \
# 0                                 0.89
# 1                                 0.93
# 2                                 0.89
# 3                                 0.91
#
#    mean perimeter + mean texture + no std  \
# 0                                    0.89
# 1                                    0.94
# 2                                    0.88
# 3                                    0.91
#
#    mean perimeter + mean smoothness + std  \
# 0                                    0.87
# 1                                    0.96
# 2                                    0.83
# 3                                    0.89
#
#    mean perimeter + mean smoothness + no std  mean area + mean texture + std  \
# 0                                       0.86                            0.88
# 1                                       0.87                            0.91
# 2                                       0.91                            0.90
# 3                                       0.89                            0.91
#
#    mean area + mean texture + no std  mean area + mean smoothness + std  \
# 0                               0.87                               0.86
# 1                               0.89                               0.95
# 2                               0.91                               0.82
# 3                               0.90                               0.88
#
#    mean area + mean smoothness + no std
# 0                                  0.87
# 1                                  0.88
# 2                                  0.92
# 3                                  0.89

# %%
pd.DataFrame(showDF(7), columns=pairs)
# Out:
# k = 7
#    mean radius + mean texture + std  mean radius + mean texture + no std  \
# 0                              0.89                                 0.89
# 1                              0.92                                 0.90
# 2                              0.92                                 0.93
# 3                              0.92                                 0.91
#
#    mean radius + mean smoothness + std  \
# 0                                 0.88
# 1                                 0.94
# 2                                 0.87
# 3                                 0.90
#
#    mean radius + mean smoothness + no std  \
# 0                                    0.87
# 1                                    0.86
# 2                                    0.93
# 3                                    0.90
#
#    mean perimeter + mean texture + std  \
# 0                                 0.92
# 1                                 0.93
# 2                                 0.93
# 3                                 0.93
#
#    mean perimeter + mean texture + no std  \
# 0                                    0.92
# 1                                    0.94
# 2                                    0.93
# 3                                    0.93
#
#    mean perimeter + mean smoothness + std  \
# 0                                    0.89
# 1                                    0.93
# 2                                    0.90
# 3                                    0.91
#
#    mean perimeter + mean smoothness + no std  mean area + mean texture + std  \
# 0                                       0.86                            0.91
# 1                                       0.86                            0.91
# 2                                       0.93                            0.94
# 3                                       0.89                            0.93
#
#    mean area + mean texture + no std  mean area + mean smoothness + std  \
# 0                               0.88                               0.88
# 1                               0.86                               0.93
# 2                               0.95                               0.87
# 3                               0.91                               0.90
#
#    mean area + mean smoothness + no std
# 0                                  0.87
# 1                                  0.86
# 2                                  0.95
# 3                                  0.90

# %%
pd.DataFrame(showDF(8), columns=pairs)
# Out:
# k = 8
#    mean radius + mean texture + std  mean radius + mean texture + no std  \
# 0                              0.88                                 0.88
# 1                              0.93                                 0.91
# 2                              0.88                                 0.90
# 3                              0.90                                 0.90
#
#    mean radius + mean smoothness + std  \
# 0                                 0.88
# 1                                 0.95
# 2                                 0.85
# 3                                 0.90
#
#    mean radius + mean smoothness + no std  \
# 0                                    0.86
# 1                                    0.86
# 2                                    0.93
# 3                                    0.89
#
#    mean perimeter + mean texture + std  \
# 0                                 0.91
# 1                                 0.95
# 2                                 0.91
# 3                                 0.93
#
#    mean perimeter + mean texture + no std  \
# 0                                    0.89
# 1                                    0.94
# 2                                    0.89
# 3                                    0.91
#
#    mean perimeter + mean smoothness + std  \
# 0                                    0.89
# 1                                    0.94
# 2                                    0.88
# 3                                    0.91
#
#    mean perimeter + mean smoothness + no std  mean area + mean texture + std  \
# 0                                       0.87                            0.89
# 1                                       0.87                            0.92
# 2                                       0.93                            0.92
# 3                                       0.90                            0.92
#
#    mean area + mean texture + no std  mean area + mean smoothness + std  \
# 0                               0.87                               0.89
# 1                               0.87                               0.95
# 2                               0.93                               0.87
# 3                               0.90                               0.91
#
#    mean area + mean smoothness + no std
# 0                                  0.86
# 1                                  0.86
# 2                                  0.93
# 3                                  0.89

# %%
pd.DataFrame(showDF(9), columns=pairs)
# Out:
# k = 9
#    mean radius + mean texture + std  mean radius + mean texture + no std  \
# 0                              0.88                                 0.89
# 1                              0.90                                 0.89
# 2                              0.92                                 0.93
# 3                              0.91                                 0.91
#
#    mean radius + mean smoothness + std  \
# 0                                 0.88
# 1                                 0.91
# 2                                 0.90
# 3                                 0.91
#
#    mean radius + mean smoothness + no std  \
# 0                                    0.86
# 1                                    0.85
# 2                                    0.94
# 3                                    0.89
#
#    mean perimeter + mean texture + std  \
# 0                                 0.93
# 1                                 0.94
# 2                                 0.95
# 3                                 0.94
#
#    mean perimeter + mean texture + no std  \
# 0                                    0.89
# 1                                    0.92
# 2                                    0.91
# 3                                    0.91
#
#    mean perimeter + mean smoothness + std  \
# 0                                    0.89
# 1                                    0.93
# 2                                    0.89
# 3                                    0.91
#
#    mean perimeter + mean smoothness + no std  mean area + mean texture + std  \
# 0                                       0.86                            0.91
# 1                                       0.85                            0.90
# 2                                       0.93                            0.96
# 3                                       0.89                            0.93
#
#    mean area + mean texture + no std  mean area + mean smoothness + std  \
# 0                               0.88                               0.89
# 1                               0.86                               0.92
# 2                               0.95                               0.90
# 3                               0.91                               0.91
#
#    mean area + mean smoothness + no std
# 0                                  0.87
# 1                                  0.86
# 2                                  0.95
# 3                                  0.90
